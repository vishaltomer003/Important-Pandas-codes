# %% [markdown]
# # What kind of data does pandas handle?

# %%
import pandas as pd
df = pd.DataFrame(
    {
        "Name": [
            "Braund, Mr. Owen Harris",
            "Allen, Mr. William Henry",
            "Bonnell, Miss. Elizabeth",
        ],
        "Age": [22, 35, 58],
        "Sex": ["male", "male", "female"],
    }
)
df
# Out:
#                        Name  Age     Sex
# 0   Braund, Mr. Owen Harris   22    male
# 1  Allen, Mr. William Henry   35    male
# 2  Bonnell, Miss. Elizabeth   58  female

# %%
# series
ages = pd.Series([22, 35, 58], name="Age")

# %%
# series 
df.describe(include='all')
# Out:
#                            Name        Age   Sex
# count                         3   3.000000     3
# unique                        3        NaN     2
# top     Braund, Mr. Owen Harris        NaN  male
# freq                          1        NaN     2
# mean                        NaN  38.333333   NaN
# std                         NaN  18.230012   NaN
# min                         NaN  22.000000   NaN
# 25%                         NaN  28.500000   NaN
# 50%                         NaN  35.000000   NaN
# 75%                         NaN  46.500000   NaN
# max                         NaN  58.000000   NaN

# %%
df = pd.read_csv(r'C:\Users\Vaishali Tomar\Desktop\Important_python_file\UP_2022.csv')
df1 = pd.read_csv(r'C:\Users\Vaishali Tomar\Desktop\Important_python_file\UP_District.csv')

# %%
# to spreadsheet
df.to_excel(r"C:\Users\Vaishali Tomar\Desktop\Important_python_file\UP_2021.xlsx", sheet_name="vote", index=False)

# %%
# reading xlsv file
df = pd.read_excel(r"C:\Users\Vaishali Tomar\Desktop\Important_python_file\UP_2021.xlsx", sheet_name="vote")

# %%
df
# Out:
#       ac_no      Candidate                               Party  Total Votes  \
# 0         1  Umar Ali Khan                     Samajwadi Party       134513
# 1         1   Naresh Saini              Bharatiya Janata Party        96633
# 2         1     Rais Malik                 Bahujan Samaj Party        45075
# 3         1  Poonam Kamboj            Indian National Congress         1632
# 4         1   Sushil Kumar                     Aam Aadmi Party         1162
# ...     ...            ...                                 ...          ...
# 4840    403   HRIDAY KUMAR                         Independent         1853
# 4841    403    ASHOK KUMAR                   Jan Adhikar Party         1758
# 4842    403     MISHRI LAL                         Independent         1317
# 4843    403   KRIPASHANKAR  All India Peoples' Front (Radical)          894
# 4844    403    PUSHPA DEVI                     Aam Aadmi Party          830
#
#       % of Votes  Rank
# 0          47.81     1
# ...

# %%
# 'ISIN' function 
class_23 = df[df["Party"].isin(['Bharatiya Janata Party','Samajwadi Party'])]

# %%
# "NOTNA"
df[df['Party'].notna()]
# Out:
#       ac_no      Candidate                               Party  Total Votes  \
# 0         1  Umar Ali Khan                     Samajwadi Party       134513
# 1         1   Naresh Saini              Bharatiya Janata Party        96633
# 2         1     Rais Malik                 Bahujan Samaj Party        45075
# 3         1  Poonam Kamboj            Indian National Congress         1632
# 4         1   Sushil Kumar                     Aam Aadmi Party         1162
# ...     ...            ...                                 ...          ...
# 4840    403   HRIDAY KUMAR                         Independent         1853
# 4841    403    ASHOK KUMAR                   Jan Adhikar Party         1758
# 4842    403     MISHRI LAL                         Independent         1317
# 4843    403   KRIPASHANKAR  All India Peoples' Front (Radical)          894
# 4844    403    PUSHPA DEVI                     Aam Aadmi Party          830
#
#       % of Votes  Rank
# 0          47.81     1
# ...

# %%
# df.iloc[0:3,2] = 'Bharatiya Janata Party'

# %%
df
# Out:
#       ac_no      Candidate                               Party  Total Votes  \
# 0         1  Umar Ali Khan              Bharatiya Janata Party       134513
# 1         1   Naresh Saini              Bharatiya Janata Party        96633
# 2         1     Rais Malik              Bharatiya Janata Party        45075
# 3         1  Poonam Kamboj            Indian National Congress         1632
# 4         1   Sushil Kumar                     Aam Aadmi Party         1162
# ...     ...            ...                                 ...          ...
# 4840    403   HRIDAY KUMAR                         Independent         1853
# 4841    403    ASHOK KUMAR                   Jan Adhikar Party         1758
# 4842    403     MISHRI LAL                         Independent         1317
# 4843    403   KRIPASHANKAR  All India Peoples' Front (Radical)          894
# 4844    403    PUSHPA DEVI                     Aam Aadmi Party          830
#
#       % of Votes  Rank
# 0          47.81     1
# ...
